# %%
import os
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("C:/Users/nkovi/Downloads/HCSCrime.csv")
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    incident_id  case_number       incident_datetime  \
# 0    878915238  180077160-1  01/01/2018 12:00:00 AM
# 1    878915747  180076342-1  01/01/2018 12:00:00 AM
# 2    878049751  180803082-1  11/13/2014 12:00:00 PM
# 3    878048267  180903126-1  02/01/2015 12:07:00 AM
# 4    880905920  181000089-1  02/22/2018 12:00:00 AM
#
#                  incident_type_primary  \
# 0                            RMS Fraud
# 1                            RMS Fraud
# 2               RMS 26C  IMPERSONATION
# 3  RMS 250  FORGERY - USING / UTTERING
# 4                     RMS Embezzlement
#
#                                 incident_description  clearance_type  \
# 0  Fraud<br/><br/>Reporting Agency: Sheriff's Office             NaN
# ...

# %%
editted_df = df[["incident_id", "incident_datetime", "zip", "created_at", "location", "day_of_week", "parent_incident_type"]]
editted_df.head()
# Out:
#    incident_id       incident_datetime    zip              created_at  \
# 0    878915238  01/01/2018 12:00:00 AM  77014  09/24/2018 06:14:59 PM
# 1    878915747  01/01/2018 12:00:00 AM  77064  09/24/2018 06:15:11 PM
# 2    878049751  11/13/2014 12:00:00 PM  77388  09/17/2018 10:22:57 PM
# 3    878048267  02/01/2015 12:07:00 AM  77379  09/17/2018 10:22:24 PM
# 4    880905920  02/22/2018 12:00:00 AM  77002  10/11/2018 11:46:48 AM
#
#                                 location day_of_week parent_incident_type
# 0           POINT (-95.461964 30.003736)      Monday                Other
# 1  POINT (-95.57446569999999 29.9290146)      Monday                Other
# 2         POINT (-95.4622797 30.0507551)    Thursday       Property Crime
# 3  POINT (-95.51151980000002 30.0118793)      Sunday       Property Crime
# 4          POINT (-95.3715163 29.744984)    Thursday                Theft

# %%
fig = px.line(editted_df, x = 'AAPL_x', y = 'AAPL_y', title='Apple Share Prices over time (2014)')
fig.show()
