# %%
import requests
import pandas as pd
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
from pprint import pprint

# %%
# Set up url
url = 'https://cohweb.houstontx.gov/ActiveIncidents/Combined.aspx?agency=P'
html = requests.get(url)
col_names = ['Address','Cross Street','Key Map','Call Time(Opened)','Incident Type','Combined Response']
address = []
cross = []
keymap = []
time = []
incident_type = []
response = []
lat = []
lon = []

# %%
# Reading the html page
soup = BeautifulSoup(html.text, "html.parser")

# %%
tbody = soup.find(id="GridView2")

# %%
#tbody.find('tr').find('th').text
tag = tbody.findAll('tr')[1:]

# %%
for tr in tag:
    print('*******')
    print(tr.find_all('td')[0].text)
    address.append(tr.find_all('td')[0].text)
    print('*******')
    print(tr.find_all('td')[1].text)
    cross.append(tr.find_all('td')[1].text)
    print('*******')
    print(tr.find_all('td')[2].text)
    keymap.append(tr.find_all('td')[2].text)
    print('*******')
    print(tr.find_all('td')[3].text)
    time.append(tr.find_all('td')[3].text)
    print('*******')
    print(tr.find_all('td')[4].text)
    incident_type.append(tr.find_all('td')[4].text)
    print('*******')
    print(tr.find_all('td')[5].text)
    response.append(tr.find_all('td')[5].text)
    print('*******')

    print('-------- NEXT TAG --------')
# Out:
# *******
# 18800 EASTEX FWY OB
# *******
# WILL CLAYTON ENTR
# *******
# 375C
# *******
# 10/21/2019 21:32
# *******
# TRAFFIC HAZARD/URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5724 KENILWOOD DR
# *******
#
# *******
# 534W
# *******
# 10/21/2019 21:06
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 6626 GULF FWY OB
# *******
# GRIGGS ENTR
# *******
# 534H
# *******
# 10/21/2019 20:40
# *******
# CRASH/MAJOR/FSRA
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7531 WESTHEIMER RD
# *******
# BLK STONEY BROOK DR
# *******
# 490V
# *******
# 10/21/2019 20:15
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7201 MAIN ST
# *******
#
# *******
# 532H
# *******
# 10/21/2019 19:58
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 6601 SOUTHWEST FWY IB
# *******
#
# *******
# 530D
# *******
# 10/21/2019 19:49
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 1316 NOBLE ST
# *******
# BLK CHAPMAN ST
# *******
# 493D
# *******
# 10/21/2019 19:43
# *******
# CRASH/MINOR/FSGI
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 12502 KATY FWY OB
# *******
#
# *******
# 488D
# *******
# 10/21/2019 19:11
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 11864 ALGONQUIN DR
# *******
#
# *******
# 576Z
# *******
# 10/21/2019 19:11
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5698 GULFTON ST
# *******
#
# *******
# 531B
# *******
# 10/21/2019 18:59
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 13333 NORTHBOROUGH DR
# *******
# BLK RUSHCREEK DR
# *******
# 372L
# *******
# 10/21/2019 18:19
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 9555 S POST OAK RD
# *******
# BLK MEYER PARK DR
# *******
# 531U
# *******
# 10/21/2019 17:57
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 201 WAUGH DR
# *******
# HEIGHTS ENTR
# *******
# 492M
# *******
# 10/21/2019 17:56
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7805 LITTLE YORK RD
# *******
#
# *******
# 415T
# *******
# 10/21/2019 17:36
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 213 CAPLIN ST
# *******
# BLK PAINE ST
# *******
# 453Q
# *******
# 10/21/2019 14:11
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 6225 BISSONNET ST
# *******
# BLK HILLCROFT AVE
# *******
# 531J
# *******
# 10/21/2019 12:25
# *******
# CRASH/MINOR/FSGI
# *******
# N
# *******
# -------- NEXT TAG --------

# %% [markdown]
# ## Alternate Approach
# m = ''
# td = ''
# for tr in tag:
#     td = tr.find_all('td')
#     print('*******')
#     print(td)
#     print('******')
#     for td in tr:
#         if td!= '\n':
#             m = td
#             print("-------------td tag------")
#             print(td)
#             print(td.text)
#             print("End of tag")
#
#     #ele[0].Contents()

# %%
tr.find_all('td')[1].text
# Out:
# 'BLK HILLCROFT AVE'

# %%
df = pd.DataFrame({'Address':address,'Cross_Street':cross,'Keymap':keymap,'Time':time,'Incident_Type':incident_type,'Response':response} )
# filter = df["Address"] != ''
#dfNew = df[filter]
#a = dfNew[dfNew['Time'] =='10/10/2019 18:32']
#a["Address"]

df_new = df[df["Address"] != '\xa0']

df_new
# df['Address'][17]
# Out:
#                    Address         Cross_Street Keymap              Time  \
# 0      18800 EASTEX FWY OB    WILL CLAYTON ENTR   375C  10/21/2019 21:32
# 1       5724 KENILWOOD DR                         534W  10/21/2019 21:06
# 2         6626 GULF FWY OB          GRIGGS ENTR   534H  10/21/2019 20:40
# 3       7531 WESTHEIMER RD  BLK STONEY BROOK DR   490V  10/21/2019 20:15
# 4            7201 MAIN ST                         532H  10/21/2019 19:58
# 5   6601 SOUTHWEST FWY IB                         530D  10/21/2019 19:49
# 6            1316 NOBLE ST       BLK CHAPMAN ST   493D  10/21/2019 19:43
# 7       12502 KATY FWY OB                         488D  10/21/2019 19:11
# 8      11864 ALGONQUIN DR                         576Z  10/21/2019 19:11
# 9         5698 GULFTON ST                         531B  10/21/2019 18:59
# 10   13333 NORTHBOROUGH DR     BLK RUSHCREEK DR   372L  10/21/2019 18:19
# 11      9555 S POST OAK RD    BLK MEYER PARK DR   531U  10/21/2019 17:57
# 12            201 WAUGH DR         HEIGHTS ENTR   492M  10/21/2019 17:56
# 13    7805 LITTLE YORK RD                         415T  10/21/2019 17:36
# 14           213 CAPLIN ST         BLK PAINE ST   453Q  10/21/2019 14:11
# 15       6225 BISSONNET ST    BLK HILLCROFT AVE   531J  10/21/2019 12:25
#
#               Incident_Type Response
# 0     TRAFFIC HAZARD/URGENT        N
# 1     CRASH/MAJOR/NON FATAL        N
# 2          CRASH/MAJOR/FSRA        N
# 3               CRASH/MINOR        N
# 4               CRASH/MINOR        N
# 5     CRASH/MAJOR/NON FATAL        N
# 6          CRASH/MINOR/FSGI        N
# 7     CRASH/MAJOR/NON FATAL        N
# 8     CRASH/MAJOR/NON FATAL        N
# 9     CRASH/MAJOR/NON FATAL        N
# 10    CRASH/MAJOR/NON FATAL        N
# 11              CRASH/MINOR        N
# 12              CRASH/MINOR        N
# 13              CRASH/MINOR        N
# 14  CRASH/MINOR/DISTURBANCE        N
# 15         CRASH/MINOR/FSGI        N

# %%
location = []
len(df_new)
# Out:
# 32

# %%
for x in range(0,len(df_new)):
    try:
        print(df['Address'][x])
        row = requests.get('https://nominatim.openstreetmap.org/search?q='+ df['Address'][x] + ',Houston,Tx&format=json')
        lat.append(row.json()[0]['lat'])
        lon.append(row.json()[0]['lon'])
        location.append([row.json()[0]['lat'],row.json()[0]['lon']])
        print('-----APPEND DONE------')
    except:
        lat.append('')
        lon.append('')
        location.append('')
        pass
# 'https://nominatim.openstreetmap.org/search?q='+ df['Address'] + ',Houston,Tx
# Out:
# 9300 RICHMOND AVE
# -----APPEND DONE------
#
# -----APPEND DONE------
# 1498 S LOOP W
# -----APPEND DONE------
# 727 BUNKER HILL RD
# -----APPEND DONE------
# 10198 ALMEDA GENOA RD
# -----APPEND DONE------
# 2198 ANTOINE DR
# -----APPEND DONE------
# 4502 CORNISH ST
# -----APPEND DONE------
# 1101 LEELAND ST
# -----APPEND DONE------
# 2900 S GESSNER RD
# -----APPEND DONE------
# 13333 NORTHBOROUGH DR
# -----APPEND DONE------
# 9898 HOLLISTER ST
# -----APPEND DONE------
# 4817 MAIN ST
# -----APPEND DONE------
# 1001 WENTWORTH ST
# -----APPEND DONE------
# 21 TIDWELL RD
# -----APPEND DONE------
# 8520 PITNER RD
# -----APPEND DONE------
# 5310 S RICE AVE
# -----APPEND DONE------
# 201 WAUGH DR
# -----APPEND DONE------
# 14818 S POST OAK RD
# -----APPEND DONE------
# 8758 HOWARD DR
# -----APPEND DONE------
# 14698 WHITE HEATHER DR
# -----APPEND DONE------
# 5509 S SAM HOUSTON PKWY W
# -----APPEND DONE------
# 799 S SH 6
# -----APPEND DONE------
# HOBBY AIRPORT 7800 AIRPORT BLVD
# 10242 IRVINGTON BLVD
# -----APPEND DONE------
# WIH10IB-SILBER RD 7693 W IH 10 FWY IB
# 10128 MONROE RD
# -----APPEND DONE------
# 7518 SAN FELIPE ST
# -----APPEND DONE------
# 8650 GULF FWY OB
# -----APPEND DONE------
# 2501 WESTHEIMER RD
# -----APPEND DONE------
# OLIVE GARDEN 12711 GULF FWY IB
# 213 CAPLIN ST
# -----APPEND DONE------
# 6225 BISSONNET ST
# -----APPEND DONE------

# %%
#df_new['lat'] = lat
#df_new['lon'] = lon

print(len(location))
print(len(df_new))
# Out:
# 32
# 32

# %%
df_new["location"] = location
df_new['lat'] = lat
df_new['lon'] = lon
df_new
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   Address            Cross_Street Keymap  \
# 0                       9300 RICHMOND AVE       BLK WESTERLAND DR   490X
# 2                          1498 S LOOP W                            532V
# 3                      727 BUNKER HILL RD             BLK GAGE CT   490F
# 4                  10198 ALMEDA GENOA RD                            576J
# 5                        2198 ANTOINE DR                            451U
# 6                         4502 CORNISH ST           BLK FOWLER ST   492H
# 7                        1101 LEELAND ST                            493Q
# 8                       2900 S GESSNER RD       BLK HIGHMEADOW DR   490S
# 9                   13333 NORTHBOROUGH DR        BLK RUSHCREEK DR   372L
# 10                     9898 HOLLISTER ST                            410R
# 11                           4817 MAIN ST         BLK ROSEDALE ST   493W
# 12                     1001 WENTWORTH ST                            493W
# 13                          21 TIDWELL RD           BLK FULTON ST   453B
# 14                         8520 PITNER RD             BLK ROMA ST   450M
# 15                        5310 S RICE AVE         BLK GLENMONT DR   491Y
# 16                           201 WAUGH DR            HEIGHTS ENTR   492M
# 17                   14818 S POST OAK RD                            571U
# 18                        8758 HOWARD DR                            535R
# 19                14698 WHITE HEATHER DR                            572S
# 20             5509 S SAM HOUSTON PKWY W                            571Y
# 21                            799 S SH 6                            488A
# 22        HOBBY AIRPORT 7800 AIRPORT BLVD      HOBBY AIRPORT EXIT   575B
# 23                  10242 IRVINGTON BLVD                            453C
# 24  WIH10IB-SILBER RD 7693 W IH 10 FWY IB  SILBER - POST OAK EXIT   491C
# 25                       10128 MONROE RD                            575P
# 26                    7518 SAN FELIPE ST                            490R
# 27                       8650 GULF FWY OB            AIRPORT EXIT   535Y
# 28                    2501 WESTHEIMER RD                            492U
# 29         OLIVE GARDEN 12711 GULF FWY IB              FUQUA EXIT   576U
# 30                          213 CAPLIN ST            BLK PAINE ST   453Q
# 31                      6225 BISSONNET ST       BLK HILLCROFT AVE   531J
# 32                       11000 E HARDY RD      BLK CHAMBERLAIN ST   413U
#
#                 Time            Incident_Type Response  \
# 0   10/21/2019 18:51    CRASH/MAJOR/NON FATAL        N
# 2   10/21/2019 18:46    TRAFFIC HAZARD/URGENT        N
# 3   10/21/2019 18:42         CRASH/MINOR/FSGI        N
# 4   10/21/2019 18:40              CRASH/MINOR        N
# 5   10/21/2019 18:35              CRASH/MINOR        N
# 6   10/21/2019 18:27         CRASH/MINOR/FSGI        N
# 7   10/21/2019 18:22              CRASH/MINOR        N
# 8   10/21/2019 18:21    CRASH/MAJOR/NON FATAL        N
# 9   10/21/2019 18:19    CRASH/MAJOR/NON FATAL        N
# 10  10/21/2019 18:16    TRAFFIC HAZARD/URGENT        N
# 11  10/21/2019 18:12    CRASH/MAJOR/NON FATAL        N
# 12  10/21/2019 18:11              CRASH/MINOR        N
# 13  10/21/2019 18:04              CRASH/MINOR        N
# 14  10/21/2019 18:02              CRASH/MINOR        N
# 15  10/21/2019 18:01         CRASH/MAJOR/FSRA        N
# 16  10/21/2019 17:56              CRASH/MINOR        N
# 17  10/21/2019 17:51              CRASH/MINOR        N
# 18  10/21/2019 17:47              CRASH/MINOR        N
# 19  10/21/2019 17:45              CRASH/MINOR        N
# 20  10/21/2019 17:40    CRASH/MAJOR/NON FATAL        N
# 21  10/21/2019 17:37              CRASH/MINOR        N
# 22  10/21/2019 17:35              CRASH/MINOR        N
# 23  10/21/2019 17:25    CRASH/MAJOR/NON FATAL        N
# 24  10/21/2019 17:25    CRASH/MAJOR/NON FATAL        N
# 25  10/21/2019 17:20         CRASH/MINOR/FSGI        N
# 26  10/21/2019 17:02              CRASH/MINOR        N
# 27  10/21/2019 16:54  CRASH/MINOR/DISTURBANCE        N
# 28  10/21/2019 16:48    CRASH/MAJOR/NON FATAL        N
# 29  10/21/2019 14:32         CRASH/MINOR/FSGI        N
# 30  10/21/2019 14:11  CRASH/MINOR/DISTURBANCE        N
# 31  10/21/2019 12:25         CRASH/MINOR/FSGI        N
# 32  10/21/2019 08:52     CRASH/MAJOR/FATALITY        N
#
#                                  location               lat                lon
# 0                [29.7285231, -95.550971]        29.7285231         -95.550971
# 2               [29.7589382, -95.3676974]        29.7589382        -95.3676974
# 3               [29.6794665, -95.4458751]        29.6794665        -95.4458751
# 4   [29.7739672244898, -95.5316680612245]  29.7739672244898  -95.5316680612245
# 5               [29.6256435, -95.2805134]        29.6256435        -95.2805134
# 6                 [29.811109, -95.475042]         29.811109         -95.475042
# 7   [29.7786285961538, -95.4064381730769]  29.7786285961538  -95.4064381730769
# 8                 [29.751948, -95.367429]         29.751948         -95.367429
# 9                 [29.734686, -95.539384]         29.734686         -95.539384
# 10  [29.9590767890994, -95.4235250747061]  29.9590767890994  -95.4235250747061
# 11                [29.883803, -95.506869]         29.883803         -95.506869
# 12              [29.6712579, -95.4326317]        29.6712579        -95.4326317
# 13                 [29.731383, -95.38499]         29.731383          -95.38499
# 14  [29.8456342492543, -95.3829100322721]  29.8456342492543  -95.3829100322721
# 15  [29.8292970913185, -95.5006378828285]  29.8292970913185  -95.5006378828285
# 16        [29.7243709, -95.4711771917257]        29.7243709  -95.4711771917257
# 17              [29.7639617, -95.3988801]        29.7639617        -95.3988801
# 18  [29.6118843846154, -95.4650512307692]  29.6118843846154  -95.4650512307692
# 19  [29.6883899924632, -95.2500150924695]  29.6883899924632  -95.2500150924695
# 20  [29.6135489772727, -95.4389429318182]  29.6135489772727  -95.4389429318182
# 21  [29.6010155204082, -95.4652545816326]  29.6010155204082  -95.4652545816326
# 22               [29.7397993, -95.644087]        29.7397993         -95.644087
# 23
# 24  [29.8543958446649, -95.3625808086038]  29.8543958446649  -95.3625808086038
# 25
# 26                 [29.61899, -95.266819]          29.61899         -95.266819
# 27               [29.7477673, -95.426577]        29.7477673         -95.426577
# 28               [29.597532, -95.1964804]         29.597532        -95.1964804
# 29                [29.742291, -95.417711]         29.742291         -95.417711
# 30
# 31  [29.8156096386152, -95.3693851405038]  29.8156096386152  -95.3693851405038
# 32  [29.6957945714286, -95.4913357857143]  29.6957945714286  -95.4913357857143

# %%
df_new = df_new[(df_new['lat']!= '') & (df_new['lon']!= '')]
df_new
# Out:
#                                   Address            Cross_Street Keymap  \
# 0                       9300 RICHMOND AVE       BLK WESTERLAND DR   490X
# 2                          1498 S LOOP W                            532V
# 3                      727 BUNKER HILL RD             BLK GAGE CT   490F
# 4                  10198 ALMEDA GENOA RD                            576J
# 5                        2198 ANTOINE DR                            451U
# 6                         4502 CORNISH ST           BLK FOWLER ST   492H
# 7                        1101 LEELAND ST                            493Q
# 8                       2900 S GESSNER RD       BLK HIGHMEADOW DR   490S
# 9                   13333 NORTHBOROUGH DR        BLK RUSHCREEK DR   372L
# 10                     9898 HOLLISTER ST                            410R
# 11                           4817 MAIN ST         BLK ROSEDALE ST   493W
# 12                     1001 WENTWORTH ST                            493W
# 13                          21 TIDWELL RD           BLK FULTON ST   453B
# 14                         8520 PITNER RD             BLK ROMA ST   450M
# 15                        5310 S RICE AVE         BLK GLENMONT DR   491Y
# 16                           201 WAUGH DR            HEIGHTS ENTR   492M
# 17                   14818 S POST OAK RD                            571U
# 18                        8758 HOWARD DR                            535R
# 19                14698 WHITE HEATHER DR                            572S
# 20             5509 S SAM HOUSTON PKWY W                            571Y
# 21                            799 S SH 6                            488A
# 22        HOBBY AIRPORT 7800 AIRPORT BLVD      HOBBY AIRPORT EXIT   575B
# 24  WIH10IB-SILBER RD 7693 W IH 10 FWY IB  SILBER - POST OAK EXIT   491C
# 26                    7518 SAN FELIPE ST                            490R
# 27                       8650 GULF FWY OB            AIRPORT EXIT   535Y
# 28                    2501 WESTHEIMER RD                            492U
# 29         OLIVE GARDEN 12711 GULF FWY IB              FUQUA EXIT   576U
# 31                      6225 BISSONNET ST       BLK HILLCROFT AVE   531J
# 32                       11000 E HARDY RD      BLK CHAMBERLAIN ST   413U
#
#                 Time            Incident_Type Response  \
# 0   10/21/2019 18:51    CRASH/MAJOR/NON FATAL        N
# 2   10/21/2019 18:46    TRAFFIC HAZARD/URGENT        N
# 3   10/21/2019 18:42         CRASH/MINOR/FSGI        N
# 4   10/21/2019 18:40              CRASH/MINOR        N
# 5   10/21/2019 18:35              CRASH/MINOR        N
# 6   10/21/2019 18:27         CRASH/MINOR/FSGI        N
# 7   10/21/2019 18:22              CRASH/MINOR        N
# 8   10/21/2019 18:21    CRASH/MAJOR/NON FATAL        N
# 9   10/21/2019 18:19    CRASH/MAJOR/NON FATAL        N
# 10  10/21/2019 18:16    TRAFFIC HAZARD/URGENT        N
# 11  10/21/2019 18:12    CRASH/MAJOR/NON FATAL        N
# 12  10/21/2019 18:11              CRASH/MINOR        N
# 13  10/21/2019 18:04              CRASH/MINOR        N
# 14  10/21/2019 18:02              CRASH/MINOR        N
# 15  10/21/2019 18:01         CRASH/MAJOR/FSRA        N
# 16  10/21/2019 17:56              CRASH/MINOR        N
# 17  10/21/2019 17:51              CRASH/MINOR        N
# 18  10/21/2019 17:47              CRASH/MINOR        N
# 19  10/21/2019 17:45              CRASH/MINOR        N
# 20  10/21/2019 17:40    CRASH/MAJOR/NON FATAL        N
# 21  10/21/2019 17:37              CRASH/MINOR        N
# 22  10/21/2019 17:35              CRASH/MINOR        N
# 24  10/21/2019 17:25    CRASH/MAJOR/NON FATAL        N
# 26  10/21/2019 17:02              CRASH/MINOR        N
# 27  10/21/2019 16:54  CRASH/MINOR/DISTURBANCE        N
# 28  10/21/2019 16:48    CRASH/MAJOR/NON FATAL        N
# 29  10/21/2019 14:32         CRASH/MINOR/FSGI        N
# 31  10/21/2019 12:25         CRASH/MINOR/FSGI        N
# 32  10/21/2019 08:52     CRASH/MAJOR/FATALITY        N
#
#                                  location               lat                lon
# 0                [29.7285231, -95.550971]        29.7285231         -95.550971
# 2               [29.7589382, -95.3676974]        29.7589382        -95.3676974
# 3               [29.6794665, -95.4458751]        29.6794665        -95.4458751
# 4   [29.7739672244898, -95.5316680612245]  29.7739672244898  -95.5316680612245
# 5               [29.6256435, -95.2805134]        29.6256435        -95.2805134
# 6                 [29.811109, -95.475042]         29.811109         -95.475042
# 7   [29.7786285961538, -95.4064381730769]  29.7786285961538  -95.4064381730769
# 8                 [29.751948, -95.367429]         29.751948         -95.367429
# 9                 [29.734686, -95.539384]         29.734686         -95.539384
# 10  [29.9590767890994, -95.4235250747061]  29.9590767890994  -95.4235250747061
# 11                [29.883803, -95.506869]         29.883803         -95.506869
# 12              [29.6712579, -95.4326317]        29.6712579        -95.4326317
# 13                 [29.731383, -95.38499]         29.731383          -95.38499
# 14  [29.8456342492543, -95.3829100322721]  29.8456342492543  -95.3829100322721
# 15  [29.8292970913185, -95.5006378828285]  29.8292970913185  -95.5006378828285
# 16        [29.7243709, -95.4711771917257]        29.7243709  -95.4711771917257
# 17              [29.7639617, -95.3988801]        29.7639617        -95.3988801
# 18  [29.6118843846154, -95.4650512307692]  29.6118843846154  -95.4650512307692
# 19  [29.6883899924632, -95.2500150924695]  29.6883899924632  -95.2500150924695
# 20  [29.6135489772727, -95.4389429318182]  29.6135489772727  -95.4389429318182
# 21  [29.6010155204082, -95.4652545816326]  29.6010155204082  -95.4652545816326
# 22               [29.7397993, -95.644087]        29.7397993         -95.644087
# 24  [29.8543958446649, -95.3625808086038]  29.8543958446649  -95.3625808086038
# 26                 [29.61899, -95.266819]          29.61899         -95.266819
# 27               [29.7477673, -95.426577]        29.7477673         -95.426577
# 28               [29.597532, -95.1964804]         29.597532        -95.1964804
# 29                [29.742291, -95.417711]         29.742291         -95.417711
# 31  [29.8156096386152, -95.3693851405038]  29.8156096386152  -95.3693851405038
# 32  [29.6957945714286, -95.4913357857143]  29.6957945714286  -95.4913357857143

# %%
df_new.to_csv('data/live_incidents.csv',index=False)

# %% [markdown]
# # FInal Json format needed -
#
#     {
#     "location": [29.6874560555556,-95.530489489899],
#     "time": "10/19/2019 01:46",
#     "type":"CRASH/MINOR	",
#     "address": "8602 SOUTHWEST FWY OB"
#   }

# %%
df_live = pd.DataFrame({'location':df_new["location"], 'time':df_new["Time"], 
                        'type':df_new["Incident_Type"], 'address':df_new["Address"]})

# %%
df_live
# Out:
#                                  location              time  \
# 0                [29.7285231, -95.550971]  10/21/2019 18:51
# 2               [29.7589382, -95.3676974]  10/21/2019 18:46
# 3               [29.6794665, -95.4458751]  10/21/2019 18:42
# 4   [29.7739672244898, -95.5316680612245]  10/21/2019 18:40
# 5               [29.6256435, -95.2805134]  10/21/2019 18:35
# 6                 [29.811109, -95.475042]  10/21/2019 18:27
# 7   [29.7786285961538, -95.4064381730769]  10/21/2019 18:22
# 8                 [29.751948, -95.367429]  10/21/2019 18:21
# 9                 [29.734686, -95.539384]  10/21/2019 18:19
# 10  [29.9590767890994, -95.4235250747061]  10/21/2019 18:16
# 11                [29.883803, -95.506869]  10/21/2019 18:12
# 12              [29.6712579, -95.4326317]  10/21/2019 18:11
# 13                 [29.731383, -95.38499]  10/21/2019 18:04
# 14  [29.8456342492543, -95.3829100322721]  10/21/2019 18:02
# 15  [29.8292970913185, -95.5006378828285]  10/21/2019 18:01
# 16        [29.7243709, -95.4711771917257]  10/21/2019 17:56
# 17              [29.7639617, -95.3988801]  10/21/2019 17:51
# 18  [29.6118843846154, -95.4650512307692]  10/21/2019 17:47
# 19  [29.6883899924632, -95.2500150924695]  10/21/2019 17:45
# 20  [29.6135489772727, -95.4389429318182]  10/21/2019 17:40
# 21  [29.6010155204082, -95.4652545816326]  10/21/2019 17:37
# 22               [29.7397993, -95.644087]  10/21/2019 17:35
# 24  [29.8543958446649, -95.3625808086038]  10/21/2019 17:25
# 26                 [29.61899, -95.266819]  10/21/2019 17:02
# 27               [29.7477673, -95.426577]  10/21/2019 16:54
# 28               [29.597532, -95.1964804]  10/21/2019 16:48
# 29                [29.742291, -95.417711]  10/21/2019 14:32
# 31  [29.8156096386152, -95.3693851405038]  10/21/2019 12:25
# 32  [29.6957945714286, -95.4913357857143]  10/21/2019 08:52
#
#                        type                                address
# 0     CRASH/MAJOR/NON FATAL                      9300 RICHMOND AVE
# 2     TRAFFIC HAZARD/URGENT                         1498 S LOOP W
# 3          CRASH/MINOR/FSGI                     727 BUNKER HILL RD
# 4               CRASH/MINOR                 10198 ALMEDA GENOA RD
# 5               CRASH/MINOR                       2198 ANTOINE DR
# 6          CRASH/MINOR/FSGI                        4502 CORNISH ST
# 7               CRASH/MINOR                       1101 LEELAND ST
# 8     CRASH/MAJOR/NON FATAL                      2900 S GESSNER RD
# 9     CRASH/MAJOR/NON FATAL                  13333 NORTHBOROUGH DR
# 10    TRAFFIC HAZARD/URGENT                     9898 HOLLISTER ST
# 11    CRASH/MAJOR/NON FATAL                           4817 MAIN ST
# 12              CRASH/MINOR                     1001 WENTWORTH ST
# 13              CRASH/MINOR                          21 TIDWELL RD
# 14              CRASH/MINOR                         8520 PITNER RD
# 15         CRASH/MAJOR/FSRA                        5310 S RICE AVE
# 16              CRASH/MINOR                           201 WAUGH DR
# 17              CRASH/MINOR                   14818 S POST OAK RD
# 18              CRASH/MINOR                        8758 HOWARD DR
# 19              CRASH/MINOR                14698 WHITE HEATHER DR
# 20    CRASH/MAJOR/NON FATAL             5509 S SAM HOUSTON PKWY W
# 21              CRASH/MINOR                            799 S SH 6
# 22              CRASH/MINOR        HOBBY AIRPORT 7800 AIRPORT BLVD
# 24    CRASH/MAJOR/NON FATAL  WIH10IB-SILBER RD 7693 W IH 10 FWY IB
# 26              CRASH/MINOR                    7518 SAN FELIPE ST
# 27  CRASH/MINOR/DISTURBANCE                       8650 GULF FWY OB
# 28    CRASH/MAJOR/NON FATAL                    2501 WESTHEIMER RD
# 29         CRASH/MINOR/FSGI         OLIVE GARDEN 12711 GULF FWY IB
# 31         CRASH/MINOR/FSGI                      6225 BISSONNET ST
# 32     CRASH/MAJOR/FATALITY                       11000 E HARDY RD

# %%
dfs_dict = df_live.to_dict('records')
pprint(dfs_dict)
# Out:
# [{'address': '9300 RICHMOND AVE',
#   'location': ['29.7285231', '-95.550971'],
#   'time': '10/21/2019 18:51',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '1498 S LOOP W ',
#   'location': ['29.7589382', '-95.3676974'],
#   'time': '10/21/2019 18:46',
#   'type': 'TRAFFIC HAZARD/URGENT'},
#  {'address': '727 BUNKER HILL RD',
#   'location': ['29.6794665', '-95.4458751'],
#   'time': '10/21/2019 18:42',
#   'type': 'CRASH/MINOR/FSGI'},
#  {'address': '10198 ALMEDA GENOA RD ',
#   'location': ['29.7739672244898', '-95.5316680612245'],
#   'time': '10/21/2019 18:40',
#   'type': 'CRASH/MINOR'},
#  {'address': '2198 ANTOINE DR ',
#   'location': ['29.6256435', '-95.2805134'],
#   'time': '10/21/2019 18:35',
#   'type': 'CRASH/MINOR'},
#  {'address': '4502 CORNISH ST',
#   'location': ['29.811109', '-95.475042'],
#   'time': '10/21/2019 18:27',
#   'type': 'CRASH/MINOR/FSGI'},
#  {'address': '1101 LEELAND ST ',
#   'location': ['29.7786285961538', '-95.4064381730769'],
#   'time': '10/21/2019 18:22',
#   'type': 'CRASH/MINOR'},
#  {'address': '2900 S GESSNER RD',
#   'location': ['29.751948', '-95.367429'],
#   'time': '10/21/2019 18:21',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '13333 NORTHBOROUGH DR',
#   'location': ['29.734686', '-95.539384'],
#   'time': '10/21/2019 18:19',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '9898 HOLLISTER ST ',
#   'location': ['29.9590767890994', '-95.4235250747061'],
#   'time': '10/21/2019 18:16',
#   'type': 'TRAFFIC HAZARD/URGENT'},
#  {'address': '4817 MAIN ST',
#   'location': ['29.883803', '-95.506869'],
#   'time': '10/21/2019 18:12',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '1001 WENTWORTH ST ',
#   'location': ['29.6712579', '-95.4326317'],
#   'time': '10/21/2019 18:11',
#   'type': 'CRASH/MINOR'},
#  {'address': '21 TIDWELL RD',
#   'location': ['29.731383', '-95.38499'],
#   'time': '10/21/2019 18:04',
#   'type': 'CRASH/MINOR'},
#  {'address': '8520 PITNER RD',
#   'location': ['29.8456342492543', '-95.3829100322721'],
#   'time': '10/21/2019 18:02',
#   'type': 'CRASH/MINOR'},
#  {'address': '5310 S RICE AVE',
#   'location': ['29.8292970913185', '-95.5006378828285'],
#   'time': '10/21/2019 18:01',
#   'type': 'CRASH/MAJOR/FSRA'},
#  {'address': '201 WAUGH DR',
#   'location': ['29.7243709', '-95.4711771917257'],
#   'time': '10/21/2019 17:56',
#   'type': 'CRASH/MINOR'},
#  {'address': '14818 S POST OAK RD ',
#   'location': ['29.7639617', '-95.3988801'],
#   'time': '10/21/2019 17:51',
#   'type': 'CRASH/MINOR'},
#  {'address': '8758 HOWARD DR ',
#   'location': ['29.6118843846154', '-95.4650512307692'],
#   'time': '10/21/2019 17:47',
#   'type': 'CRASH/MINOR'},
#  {'address': '14698 WHITE HEATHER DR ',
#   'location': ['29.6883899924632', '-95.2500150924695'],
#   'time': '10/21/2019 17:45',
#   'type': 'CRASH/MINOR'},
#  {'address': '5509 S SAM HOUSTON PKWY W ',
#   'location': ['29.6135489772727', '-95.4389429318182'],
#   'time': '10/21/2019 17:40',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '799 S SH 6 ',
#   'location': ['29.6010155204082', '-95.4652545816326'],
#   'time': '10/21/2019 17:37',
#   'type': 'CRASH/MINOR'},
#  {'address': 'HOBBY AIRPORT 7800 AIRPORT BLVD',
#   'location': ['29.7397993', '-95.644087'],
#   'time': '10/21/2019 17:35',
#   'type': 'CRASH/MINOR'},
#  {'address': 'WIH10IB-SILBER RD 7693 W IH 10 FWY IB',
#   'location': ['29.8543958446649', '-95.3625808086038'],
#   'time': '10/21/2019 17:25',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': '7518 SAN FELIPE ST ',
#   'location': ['29.61899', '-95.266819'],
#   'time': '10/21/2019 17:02',
#   'type': 'CRASH/MINOR'},
#  {'address': '8650 GULF FWY OB',
#   'location': ['29.7477673', '-95.426577'],
#   'time': '10/21/2019 16:54',
#   'type': 'CRASH/MINOR/DISTURBANCE'},
#  {'address': '2501 WESTHEIMER RD ',
#   'location': ['29.597532', '-95.1964804'],
#   'time': '10/21/2019 16:48',
#   'type': 'CRASH/MAJOR/NON FATAL'},
#  {'address': 'OLIVE GARDEN 12711 GULF FWY IB',
#   'location': ['29.742291', '-95.417711'],
#   'time': '10/21/2019 14:32',
#   'type': 'CRASH/MINOR/FSGI'},
#  {'address': '6225 BISSONNET ST',
#   'location': ['29.8156096386152', '-95.3693851405038'],
#   'time': '10/21/2019 12:25',
#   'type': 'CRASH/MINOR/FSGI'},
#  {'address': '11000 E HARDY RD',
#   'location': ['29.6957945714286', '-95.4913357857143'],
#   'time': '10/21/2019 08:52',
#   'type': 'CRASH/MAJOR/FATALITY'}]

# %% [markdown]
# ## Insert to Mongo CLoud (MLab)

# %%
import sys
import pymongo
from pprint import pprint

#db name: heroku_jq1zsq2q
# db user : livecrime_user

# %%
uri = "mongodb://livecrime_user:track#txN0W@ds137498.mlab.com:37498/heroku_jq1zsq2q?retryWrites=false"
client = pymongo.MongoClient(uri)

# %%
db = client.heroku_jq1zsq2q

# %%
db
# Out:
# Database(MongoClient(host=['ds137498.mlab.com:37498'], document_class=dict, tz_aware=False, connect=True, retrywrites=False), 'heroku_jq1zsq2q')

# %%
# Get the collection names in the database
db.collection_names()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
# ['livedata', 'system.indexes', 'crimetracker']

# %%
db.livedata.drop()

# %%
db.collection_names()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['system.indexes', 'crimetracker']

# %%
#db.livedata.insert_many(dfs_dict)
livedata = db['livedata']

# %%
livedata.insert_many(dfs_dict)

# %%
data = list(db.livedata.find())

# %%
data
# Out:
# [{'_id': ObjectId('5dae687af86e8310bd37609d'),
#   'location': ['29.7285231', '-95.550971'],
#   'time': '10/21/2019 18:51',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '9300 RICHMOND AVE'},
#  {'_id': ObjectId('5dae687af86e8310bd37609e'),
#   'location': ['29.7589382', '-95.3676974'],
#   'time': '10/21/2019 18:46',
#   'type': 'TRAFFIC HAZARD/URGENT',
#   'address': '1498 S LOOP W '},
#  {'_id': ObjectId('5dae687af86e8310bd37609f'),
#   'location': ['29.6794665', '-95.4458751'],
#   'time': '10/21/2019 18:42',
#   'type': 'CRASH/MINOR/FSGI',
#   'address': '727 BUNKER HILL RD'},
#  {'_id': ObjectId('5dae687af86e8310bd3760a0'),
#   'location': ['29.7739672244898', '-95.5316680612245'],
#   'time': '10/21/2019 18:40',
#   'type': 'CRASH/MINOR',
#   'address': '10198 ALMEDA GENOA RD '},
#  {'_id': ObjectId('5dae687af86e8310bd3760a1'),
#   'location': ['29.6256435', '-95.2805134'],
#   'time': '10/21/2019 18:35',
#   'type': 'CRASH/MINOR',
#   'address': '2198 ANTOINE DR '},
#  {'_id': ObjectId('5dae687af86e8310bd3760a2'),
#   'location': ['29.811109', '-95.475042'],
#   'time': '10/21/2019 18:27',
#   'type': 'CRASH/MINOR/FSGI',
#   'address': '4502 CORNISH ST'},
#  {'_id': ObjectId('5dae687af86e8310bd3760a3'),
#   'location': ['29.7786285961538', '-95.4064381730769'],
#   'time': '10/21/2019 18:22',
#   'type': 'CRASH/MINOR',
#   'address': '1101 LEELAND ST '},
#  {'_id': ObjectId('5dae687af86e8310bd3760a4'),
#   'location': ['29.751948', '-95.367429'],
#   'time': '10/21/2019 18:21',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '2900 S GESSNER RD'},
#  {'_id': ObjectId('5dae687af86e8310bd3760a5'),
#   'location': ['29.734686', '-95.539384'],
#   'time': '10/21/2019 18:19',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '13333 NORTHBOROUGH DR'},
#  {'_id': ObjectId('5dae687af86e8310bd3760a6'),
#   'location': ['29.9590767890994', '-95.4235250747061'],
#   'time': '10/21/2019 18:16',
#   'type': 'TRAFFIC HAZARD/URGENT',
#   'address': '9898 HOLLISTER ST '},
#  {'_id': ObjectId('5dae687af86e8310bd3760a7'),
#   'location': ['29.883803', '-95.506869'],
#   'time': '10/21/2019 18:12',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '4817 MAIN ST'},
#  {'_id': ObjectId('5dae687af86e8310bd3760a8'),
#   'location': ['29.6712579', '-95.4326317'],
#   'time': '10/21/2019 18:11',
#   'type': 'CRASH/MINOR',
#   'address': '1001 WENTWORTH ST '},
#  {'_id': ObjectId('5dae687af86e8310bd3760a9'),
#   'location': ['29.731383', '-95.38499'],
#   'time': '10/21/2019 18:04',
#   'type': 'CRASH/MINOR',
#   'address': '21 TIDWELL RD'},
#  {'_id': ObjectId('5dae687af86e8310bd3760aa'),
#   'location': ['29.8456342492543', '-95.3829100322721'],
#   'time': '10/21/2019 18:02',
#   'type': 'CRASH/MINOR',
#   'address': '8520 PITNER RD'},
#  {'_id': ObjectId('5dae687af86e8310bd3760ab'),
#   'location': ['29.8292970913185', '-95.5006378828285'],
#   'time': '10/21/2019 18:01',
#   'type': 'CRASH/MAJOR/FSRA',
#   'address': '5310 S RICE AVE'},
#  {'_id': ObjectId('5dae687af86e8310bd3760ac'),
#   'location': ['29.7243709', '-95.4711771917257'],
#   'time': '10/21/2019 17:56',
#   'type': 'CRASH/MINOR',
#   'address': '201 WAUGH DR'},
#  {'_id': ObjectId('5dae687af86e8310bd3760ad'),
#   'location': ['29.7639617', '-95.3988801'],
#   'time': '10/21/2019 17:51',
#   'type': 'CRASH/MINOR',
#   'address': '14818 S POST OAK RD '},
#  {'_id': ObjectId('5dae687af86e8310bd3760ae'),
#   'location': ['29.6118843846154', '-95.4650512307692'],
#   'time': '10/21/2019 17:47',
#   'type': 'CRASH/MINOR',
#   'address': '8758 HOWARD DR '},
#  {'_id': ObjectId('5dae687af86e8310bd3760af'),
#   'location': ['29.6883899924632', '-95.2500150924695'],
#   'time': '10/21/2019 17:45',
#   'type': 'CRASH/MINOR',
#   'address': '14698 WHITE HEATHER DR '},
#  {'_id': ObjectId('5dae687af86e8310bd3760b0'),
#   'location': ['29.6135489772727', '-95.4389429318182'],
#   'time': '10/21/2019 17:40',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '5509 S SAM HOUSTON PKWY W '},
#  {'_id': ObjectId('5dae687af86e8310bd3760b1'),
#   'location': ['29.6010155204082', '-95.4652545816326'],
#   'time': '10/21/2019 17:37',
#   'type': 'CRASH/MINOR',
#   'address': '799 S SH 6 '},
#  {'_id': ObjectId('5dae687af86e8310bd3760b2'),
#   'location': ['29.7397993', '-95.644087'],
#   'time': '10/21/2019 17:35',
#   'type': 'CRASH/MINOR',
#   'address': 'HOBBY AIRPORT 7800 AIRPORT BLVD'},
#  {'_id': ObjectId('5dae687af86e8310bd3760b3'),
#   'location': ['29.8543958446649', '-95.3625808086038'],
#   'time': '10/21/2019 17:25',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': 'WIH10IB-SILBER RD 7693 W IH 10 FWY IB'},
#  {'_id': ObjectId('5dae687af86e8310bd3760b4'),
#   'location': ['29.61899', '-95.266819'],
#   'time': '10/21/2019 17:02',
#   'type': 'CRASH/MINOR',
#   'address': '7518 SAN FELIPE ST '},
#  {'_id': ObjectId('5dae687af86e8310bd3760b5'),
#   'location': ['29.7477673', '-95.426577'],
#   'time': '10/21/2019 16:54',
#   'type': 'CRASH/MINOR/DISTURBANCE',
#   'address': '8650 GULF FWY OB'},
#  {'_id': ObjectId('5dae687af86e8310bd3760b6'),
#   'location': ['29.597532', '-95.1964804'],
#   'time': '10/21/2019 16:48',
#   'type': 'CRASH/MAJOR/NON FATAL',
#   'address': '2501 WESTHEIMER RD '},
#  {'_id': ObjectId('5dae687af86e8310bd3760b7'),
#   'location': ['29.742291', '-95.417711'],
#   'time': '10/21/2019 14:32',
#   'type': 'CRASH/MINOR/FSGI',
#   'address': 'OLIVE GARDEN 12711 GULF FWY IB'},
#  {'_id': ObjectId('5dae687af86e8310bd3760b8'),
#   'location': ['29.8156096386152', '-95.3693851405038'],
#   'time': '10/21/2019 12:25',
#   'type': 'CRASH/MINOR/FSGI',
#   'address': '6225 BISSONNET ST'},
#  {'_id': ObjectId('5dae687af86e8310bd3760b9'),
#   'location': ['29.6957945714286', '-95.4913357857143'],
#   'time': '10/21/2019 08:52',
#   'type': 'CRASH/MAJOR/FATALITY',
#   'address': '11000 E HARDY RD'}]

# %%
len(data)
# Out:
# 29

# %%
db.crimetracker.drop()

# %%
db.collection_names()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['system.indexes', 'livedata']
