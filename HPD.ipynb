# %%
import requests
import pandas as pd
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# Set up url
url = 'https://cohweb.houstontx.gov/ActiveIncidents/Combined.aspx?agency=P'
html = requests.get(url)
col_names = ['Address','Cross Street','Key Map','Call Time(Opened)','Incident Type','Combined Response']
address = []
cross = []
keymap = []
time = []
incident_type = []
response = []
lat = []
lon = []

# %%
# Reading the html page
soup = BeautifulSoup(html.text, "html.parser")

# %%
tbody = soup.find(id="GridView2")

# %%
#tbody.find('tr').find('th').text
tag = tbody.findAll('tr')[1:]

# %%
for tr in tag:
    print('*******')
    print(tr.find_all('td')[0].text)
    address.append(tr.find_all('td')[0].text)
    print('*******')
    print(tr.find_all('td')[1].text)
    cross.append(tr.find_all('td')[1].text)
    print('*******')
    print(tr.find_all('td')[2].text)
    keymap.append(tr.find_all('td')[2].text)
    print('*******')
    print(tr.find_all('td')[3].text)
    time.append(tr.find_all('td')[3].text)
    print('*******')
    print(tr.find_all('td')[4].text)
    incident_type.append(tr.find_all('td')[4].text)
    print('*******')
    print(tr.find_all('td')[5].text)
    response.append(tr.find_all('td')[5].text)
    print('*******')

    print('-------- NEXT TAG --------')
# Out:
# *******
# 11400 FUQUA ST
# *******
# GULF FWY ENTR IB
# *******
# 576U
# *******
# 10/10/2019 23:05
# *******
# TRAFFIC HAZARD/NON URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# GULF-FUQUA ST 12699 GULF FWY IB
# *******
# FUQUA EXIT
# *******
# 576U
# *******
# 10/10/2019 22:51
# *******
# CRASH/MAJOR/FSRA
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 13098 COOPERS HAWK DR
# *******
#
# *******
# 377W
# *******
# 10/10/2019 22:38
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 20698 ALDINE WESTFIELD RD
# *******
#
# *******
# 333Q
# *******
# 10/10/2019 22:38
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7200 PINEMONT DR
# *******
# BLK LANGFIELD RD
# *******
# 451E
# *******
# 10/10/2019 22:31
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 10200 WESTVIEW DR
# *******
# BLK MURRAYHILL DR
# *******
# 450W
# *******
# 10/10/2019 22:30
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 2604 SOUTHWEST FWY IB
# *******
#
# *******
# 492Y
# *******
# 10/10/2019 22:25
# *******
# TRAFFIC HAZARD/URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 11998 S SAM HOUSTON PKWY W
# *******
#
# *******
# 570A
# *******
# 10/10/2019 22:07
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 14700 HIRAM CLARKE RD
# *******
# BLK SMOOTH OAK LN
# *******
# 571V
# *******
# 10/10/2019 22:03
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 2298 CAROLINE ST
# *******
#
# *******
# 493U
# *******
# 10/10/2019 21:59
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 1003 W OREM DR
# *******
#
# *******
# 573N
# *******
# 10/10/2019 21:54
# *******
# CRASH/MINOR/FSGI
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7200 SOUTHWEST FWY OB
# *******
#
# *******
# 530G
# *******
# 10/10/2019 21:52
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 601 PINELOCH DR
# *******
#
# *******
# 617M
# *******
# 10/10/2019 21:48
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 9530 MAIN ST
# *******
# BLK BUFFALO SPEEDWAY
# *******
# 532P
# *******
# 10/10/2019 20:37
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 1601 TEXAS ST
# *******
#
# *******
# 493R
# *******
# 10/10/2019 20:31
# *******
# TRAFFIC HAZARD/NON URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 9550 BISSONNET ST
# *******
# BLK PLAINFIELD ST
# *******
# 530S
# *******
# 10/10/2019 20:08
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 9889 BELLAIRE BLVD
# *******
# BLK W SAM HOUSTON PKWY S
# *******
# 529H
# *******
# 10/10/2019 19:30
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 735 LINK RD
# *******
# BLK EASTMAN ST
# *******
# 453T
# *******
# 10/10/2019 19:18
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 3352 OLD SPANISH TRL
# *******
# BLK PEERLESS ST
# *******
# 533L
# *******
# 10/10/2019 18:19
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------

# %% [markdown]
# ## Alternate Approach
# m = ''
# td = ''
# for tr in tag:
#     td = tr.find_all('td')
#     print('*******')
#     print(td)
#     print('******')
#     for td in tr:
#         if td!= '\n':
#             m = td
#             print("-------------td tag------")
#             print(td)
#             print(td.text)
#             print("End of tag")
#
#     #ele[0].Contents()

# %%
tr.find_all('td')[1].text
# Out:
# 'BLK PEERLESS ST'

# %%
df = pd.DataFrame({'Address':address,'Cross_Street':cross,'Keymap':keymap,'Time':time,'Incident_Type':incident_type,'Response':response} )
# filter = df["Address"] != ''
dfNew = df[filter]
#a = dfNew[dfNew['Time'] =='10/10/2019 18:32']
#a["Address"]

df_new = df[df["Address"] != '\xa0']

df_new
# df['Address'][17]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                             Address              Cross_Street Keymap  \
# 0                    11400 FUQUA ST          GULF FWY ENTR IB   576U
# 1   GULF-FUQUA ST 12699 GULF FWY IB                FUQUA EXIT   576U
# 2            13098 COOPERS HAWK DR                              377W
# 3        20698 ALDINE WESTFIELD RD                              333Q
# 4                  7200 PINEMONT DR          BLK LANGFIELD RD   451E
# 5                 10200 WESTVIEW DR         BLK MURRAYHILL DR   450W
# 6            2604 SOUTHWEST FWY IB                              492Y
# 7       11998 S SAM HOUSTON PKWY W                              570A
# 8             14700 HIRAM CLARKE RD         BLK SMOOTH OAK LN   571V
# 9                 2298 CAROLINE ST                              493U
# 10                  1003 W OREM DR                              573N
# 11           7200 SOUTHWEST FWY OB                              530G
# 12                 601 PINELOCH DR                              617M
# 13                     9530 MAIN ST      BLK BUFFALO SPEEDWAY   532P
# 14                   1601 TEXAS ST                              493R
# 15                9550 BISSONNET ST         BLK PLAINFIELD ST   530S
# 16               9889 BELLAIRE BLVD  BLK W SAM HOUSTON PKWY S   529H
# 17                      735 LINK RD            BLK EASTMAN ST   453T
# 18             3352 OLD SPANISH TRL           BLK PEERLESS ST   533L
#
#                 Time              Incident_Type Response
# 0   10/10/2019 23:05  TRAFFIC HAZARD/NON URGENT        N
# 1   10/10/2019 22:51           CRASH/MAJOR/FSRA        N
# 2   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N
# 3   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N
# 4   10/10/2019 22:31                CRASH/MINOR        N
# 5   10/10/2019 22:30      CRASH/MAJOR/NON FATAL        N
# 6   10/10/2019 22:25      TRAFFIC HAZARD/URGENT        N
# 7   10/10/2019 22:07                CRASH/MINOR        N
# 8   10/10/2019 22:03                CRASH/MINOR        N
# 9   10/10/2019 21:59                CRASH/MINOR        N
# 10  10/10/2019 21:54           CRASH/MINOR/FSGI        N
# 11  10/10/2019 21:52    CRASH/MINOR/DISTURBANCE        N
# 12  10/10/2019 21:48                CRASH/MINOR        N
# 13  10/10/2019 20:37                CRASH/MINOR        N
# 14  10/10/2019 20:31  TRAFFIC HAZARD/NON URGENT        N
# 15  10/10/2019 20:08      CRASH/MAJOR/NON FATAL        N
# 16  10/10/2019 19:30    CRASH/MINOR/DISTURBANCE        N
# 17  10/10/2019 19:18      CRASH/MAJOR/NON FATAL        N
# 18  10/10/2019 18:19                CRASH/MINOR        N

# %%
len(df_new)
# Out:
# 19

# %%
for x in range(0,len(df_new)):
    try:
        print(df['Address'][x])
        row = requests.get('https://nominatim.openstreetmap.org/search?q='+ df['Address'][x] + ',Houston,Tx&format=json')
        lat.append(row.json()[0]['lat'])
        lon.append(row.json()[0]['lon'])
        print('-----APPEND DONE------')
    except:
        lat.append('')
        lon.append('')
        pass
# 'https://nominatim.openstreetmap.org/search?q='+ df['Address'] + ',Houston,Tx
# Out:
# 11400 FUQUA ST
# -----APPEND DONE------
# GULF-FUQUA ST 12699 GULF FWY IB
# 13098 COOPERS HAWK DR
# -----APPEND DONE------
# 20698 ALDINE WESTFIELD RD
# -----APPEND DONE------
# 7200 PINEMONT DR
# -----APPEND DONE------
# 10200 WESTVIEW DR
# -----APPEND DONE------
# 2604 SOUTHWEST FWY IB
# 11998 S SAM HOUSTON PKWY W
# -----APPEND DONE------
# 14700 HIRAM CLARKE RD
# -----APPEND DONE------
# 2298 CAROLINE ST
# -----APPEND DONE------
# 1003 W OREM DR
# -----APPEND DONE------
# 7200 SOUTHWEST FWY OB
# -----APPEND DONE------
# 601 PINELOCH DR
# -----APPEND DONE------
# 9530 MAIN ST
# -----APPEND DONE------
# 1601 TEXAS ST
# -----APPEND DONE------
# 9550 BISSONNET ST
# -----APPEND DONE------
# 9889 BELLAIRE BLVD
# -----APPEND DONE------
# 735 LINK RD
# -----APPEND DONE------
# 3352 OLD SPANISH TRL
# -----APPEND DONE------

# %%
df_new['lat'] = lat
df_new['lon'] = lon

# %%
df_new
# Out:
#                             Address              Cross_Street Keymap  \
# 0                    11400 FUQUA ST          GULF FWY ENTR IB   576U
# 1   GULF-FUQUA ST 12699 GULF FWY IB                FUQUA EXIT   576U
# 2            13098 COOPERS HAWK DR                              377W
# 3        20698 ALDINE WESTFIELD RD                              333Q
# 4                  7200 PINEMONT DR          BLK LANGFIELD RD   451E
# 5                 10200 WESTVIEW DR         BLK MURRAYHILL DR   450W
# 6            2604 SOUTHWEST FWY IB                              492Y
# 7       11998 S SAM HOUSTON PKWY W                              570A
# 8             14700 HIRAM CLARKE RD         BLK SMOOTH OAK LN   571V
# 9                 2298 CAROLINE ST                              493U
# 10                  1003 W OREM DR                              573N
# 11           7200 SOUTHWEST FWY OB                              530G
# 12                 601 PINELOCH DR                              617M
# 13                     9530 MAIN ST      BLK BUFFALO SPEEDWAY   532P
# 14                   1601 TEXAS ST                              493R
# 15                9550 BISSONNET ST         BLK PLAINFIELD ST   530S
# 16               9889 BELLAIRE BLVD  BLK W SAM HOUSTON PKWY S   529H
# 17                      735 LINK RD            BLK EASTMAN ST   453T
# 18             3352 OLD SPANISH TRL           BLK PEERLESS ST   533L
#
#                 Time              Incident_Type Response               lat  \
# 0   10/10/2019 23:05  TRAFFIC HAZARD/NON URGENT        N          29.61469
# 1   10/10/2019 22:51           CRASH/MAJOR/FSRA        N
# 2   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N         29.925758
# 3   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N         30.014737
# 4   10/10/2019 22:31                CRASH/MINOR        N  29.8414568627451
# 5   10/10/2019 22:30      CRASH/MAJOR/NON FATAL        N         29.790866
# 6   10/10/2019 22:25      TRAFFIC HAZARD/URGENT        N
# 7   10/10/2019 22:07                CRASH/MINOR        N        29.6053344
# 8   10/10/2019 22:03                CRASH/MINOR        N         29.613215
# 9   10/10/2019 21:59                CRASH/MINOR        N         29.745844
# 10  10/10/2019 21:54           CRASH/MINOR/FSGI        N        29.6277989
# 11  10/10/2019 21:52    CRASH/MINOR/DISTURBANCE        N        29.7313826
# 12  10/10/2019 21:48                CRASH/MINOR        N         29.570342
# 13  10/10/2019 20:37                CRASH/MINOR        N        29.6569803
# 14  10/10/2019 20:31  TRAFFIC HAZARD/NON URGENT        N         29.756857
# 15  10/10/2019 20:08      CRASH/MAJOR/NON FATAL        N        29.6764688
# 16  10/10/2019 19:30    CRASH/MINOR/DISTURBANCE        N        29.7050898
# 17  10/10/2019 19:18      CRASH/MAJOR/NON FATAL        N  29.8083852550336
# 18  10/10/2019 18:19                CRASH/MINOR        N  29.7015891111111
#
#                   lon
# 0          -95.217551
# 1
# 2          -95.190649
# 3          -95.377028
# 4   -95.4991699019608
# 5          -95.549237
# 6
# 7         -95.4772572
# 8          -95.445998
# 9          -95.370008
# 10        -95.4136416
# 11        -95.3951555
# 12         -95.149306
# 13        -95.4418238
# 14         -95.357192
# 15        -95.5301454
# 16        -95.5193628
# 17  -95.3797065234899
# 18  -95.3714433333333

# %%
df_new = df_new[(df_new['lat']!= '') & (df_new['lon']!= '')]
df_new
# Out:
#                         Address              Cross_Street Keymap  \
# 0                11400 FUQUA ST          GULF FWY ENTR IB   576U
# 2        13098 COOPERS HAWK DR                              377W
# 3    20698 ALDINE WESTFIELD RD                              333Q
# 4              7200 PINEMONT DR          BLK LANGFIELD RD   451E
# 5             10200 WESTVIEW DR         BLK MURRAYHILL DR   450W
# 7   11998 S SAM HOUSTON PKWY W                              570A
# 8         14700 HIRAM CLARKE RD         BLK SMOOTH OAK LN   571V
# 9             2298 CAROLINE ST                              493U
# 10              1003 W OREM DR                              573N
# 11       7200 SOUTHWEST FWY OB                              530G
# 12             601 PINELOCH DR                              617M
# 13                 9530 MAIN ST      BLK BUFFALO SPEEDWAY   532P
# 14               1601 TEXAS ST                              493R
# 15            9550 BISSONNET ST         BLK PLAINFIELD ST   530S
# 16           9889 BELLAIRE BLVD  BLK W SAM HOUSTON PKWY S   529H
# 17                  735 LINK RD            BLK EASTMAN ST   453T
# 18         3352 OLD SPANISH TRL           BLK PEERLESS ST   533L
#
#                 Time              Incident_Type Response               lat  \
# 0   10/10/2019 23:05  TRAFFIC HAZARD/NON URGENT        N          29.61469
# 2   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N         29.925758
# 3   10/10/2019 22:38      CRASH/MAJOR/NON FATAL        N         30.014737
# 4   10/10/2019 22:31                CRASH/MINOR        N  29.8414568627451
# 5   10/10/2019 22:30      CRASH/MAJOR/NON FATAL        N         29.790866
# 7   10/10/2019 22:07                CRASH/MINOR        N        29.6053344
# 8   10/10/2019 22:03                CRASH/MINOR        N         29.613215
# 9   10/10/2019 21:59                CRASH/MINOR        N         29.745844
# 10  10/10/2019 21:54           CRASH/MINOR/FSGI        N        29.6277989
# 11  10/10/2019 21:52    CRASH/MINOR/DISTURBANCE        N        29.7313826
# 12  10/10/2019 21:48                CRASH/MINOR        N         29.570342
# 13  10/10/2019 20:37                CRASH/MINOR        N        29.6569803
# 14  10/10/2019 20:31  TRAFFIC HAZARD/NON URGENT        N         29.756857
# 15  10/10/2019 20:08      CRASH/MAJOR/NON FATAL        N        29.6764688
# 16  10/10/2019 19:30    CRASH/MINOR/DISTURBANCE        N        29.7050898
# 17  10/10/2019 19:18      CRASH/MAJOR/NON FATAL        N  29.8083852550336
# 18  10/10/2019 18:19                CRASH/MINOR        N  29.7015891111111
#
#                   lon
# 0          -95.217551
# 2          -95.190649
# 3          -95.377028
# 4   -95.4991699019608
# 5          -95.549237
# 7         -95.4772572
# 8          -95.445998
# 9          -95.370008
# 10        -95.4136416
# 11        -95.3951555
# 12         -95.149306
# 13        -95.4418238
# 14         -95.357192
# 15        -95.5301454
# 16        -95.5193628
# 17  -95.3797065234899
# 18  -95.3714433333333

# %%
df_new.to_csv('data/live_incidents.csv',index=False)
