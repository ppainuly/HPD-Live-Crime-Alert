# %%
import requests
import pandas as pd
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# Set up url
url = 'https://cohweb.houstontx.gov/ActiveIncidents/Combined.aspx?agency=P'
html = requests.get(url)
col_names = ['Address','Cross Street','Key Map','Call Time(Opened)','Incident Type','Combined Response']
address = []
cross = []
keymap = []
time = []
incident_type = []
response = []
lat = []
lon = []

# %%
# Reading the html page
soup = BeautifulSoup(html.text, "html.parser")

# %%
tbody = soup.find(id="GridView2")

# %%
#tbody.find('tr').find('th').text
tag = tbody.findAll('tr')[1:]

# %%
for tr in tag:
    print('*******')
    print(tr.find_all('td')[0].text)
    address.append(tr.find_all('td')[0].text)
    print('*******')
    print(tr.find_all('td')[1].text)
    cross.append(tr.find_all('td')[1].text)
    print('*******')
    print(tr.find_all('td')[2].text)
    keymap.append(tr.find_all('td')[2].text)
    print('*******')
    print(tr.find_all('td')[3].text)
    time.append(tr.find_all('td')[3].text)
    print('*******')
    print(tr.find_all('td')[4].text)
    incident_type.append(tr.find_all('td')[4].text)
    print('*******')
    print(tr.find_all('td')[5].text)
    response.append(tr.find_all('td')[5].text)
    print('*******')

    print('-------- NEXT TAG --------')
# Out:
# *******
# 3234 MCGOWEN ST
# *******
# BLK TIERWESTER ST
# *******
# 493Z
# *******
# 10/20/2019 19:18
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 18000 LEE RD
# *******
# BLK WILL CLAYTON PKWY OB
# *******
# 374H
# *******
# 10/20/2019 19:16
# *******
# TRAFFIC HAZARD/URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 4454 BLALOCK RD
# *******
#
# *******
# 450G
# *******
# 10/20/2019 19:14
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 8298 BELLAIRE BLVD
# *******
#
# *******
# 530F
# *******
# 10/20/2019 19:14
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 6100 WILCREST DR
# *******
# BLK HIGH STAR DR
# *******
# 529C
# *******
# 10/20/2019 19:10
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7298 DIXIE DR
# *******
#
# *******
# 534R
# *******
# 10/20/2019 19:00
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 3398 MCCRAREY DR
# *******
#
# *******
# 411R
# *******
# 10/20/2019 18:48
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 3990 KIRBY DR
# *******
#
# *******
# 492Y
# *******
# 10/20/2019 18:23
# *******
# CRASH/MINOR/FSGI
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 3790 W SAM HOUSTON PKWY S
# *******
#
# *******
# 529D
# *******
# 10/20/2019 18:23
# *******
# TRAFFIC HAZARD/URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 10798 CENTREPARK DR
# *******
#
# *******
# 449M
# *******
# 10/20/2019 18:23
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7898 AIRLINE DR
# *******
#
# *******
# 413T
# *******
# 10/20/2019 18:10
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 1220 BLALOCK RD
# *******
# BLK WESTVIEW DR
# *******
# 450Y
# *******
# 10/20/2019 18:04
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5300 NETT ST
# *******
# BLK DETERING ST
# *******
# 492G
# *******
# 10/20/2019 17:58
# *******
# TRAFFIC HAZARD/NON URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 7698 KEMPWOOD DR
# *******
#
# *******
# 451P
# *******
# 10/20/2019 17:31
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5602 SOUTHWEST FWY OB
# *******
# CHIMNEY ROCK ENTR
# *******
# 491X
# *******
# 10/20/2019 17:29
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 13500 DUNLAP ST
# *******
# BLK HILLCROFT AVE
# *******
# 571J
# *******
# 10/20/2019 17:22
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5201 WRIGHT RD
# *******
#
# *******
# 374D
# *******
# 10/20/2019 17:20
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 3898 CLEAR LAKE CITY BLVD
# *******
#
# *******
# 578X
# *******
# 10/20/2019 16:50
# *******
# CRASH/MINOR
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 2501 MONTROSE BLVD
# *******
#
# *******
# 493N
# *******
# 10/20/2019 16:21
# *******
# TRAFFIC HAZARD/URGENT
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 9498 FONDREN RD
# *******
#
# *******
# 530V
# *******
# 10/20/2019 16:17
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5500 EL CAMINO DEL REY ST
# *******
# BLK ALDER DR
# *******
# 531B
# *******
# 10/20/2019 15:50
# *******
# CRASH/MINOR/DISTURBANCE
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 8541 WINKLER DR
# *******
# BLK MILREDGE ST
# *******
# 535U
# *******
# 10/20/2019 15:50
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5220 FUQUA GARDENS VIEW RD
# *******
# BLK NELSON ST
# *******
# 571U
# *******
# 10/20/2019 15:17
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 5000 ALLEN GENOA RD
# *******
# BLK HERNANDEZ RD
# *******
# 577J
# *******
# 10/20/2019 14:59
# *******
# CRASH/MAJOR/FSRA
# *******
# N
# *******
# -------- NEXT TAG --------
# *******
# 24771 E LAKE HOUSTON PKWY
# *******
#
# *******
# 339J
# *******
# 10/20/2019 01:10
# *******
# CRASH/MAJOR/NON FATAL
# *******
# N
# *******
# -------- NEXT TAG --------

# %% [markdown]
# ## Alternate Approach
# m = ''
# td = ''
# for tr in tag:
#     td = tr.find_all('td')
#     print('*******')
#     print(td)
#     print('******')
#     for td in tr:
#         if td!= '\n':
#             m = td
#             print("-------------td tag------")
#             print(td)
#             print(td.text)
#             print("End of tag")
#
#     #ele[0].Contents()

# %%
tr.find_all('td')[1].text
# Out:
# '\xa0'

# %%
df = pd.DataFrame({'Address':address,'Cross_Street':cross,'Keymap':keymap,'Time':time,'Incident_Type':incident_type,'Response':response} )
# filter = df["Address"] != ''
#dfNew = df[filter]
#a = dfNew[dfNew['Time'] =='10/10/2019 18:32']
#a["Address"]

df_new = df[df["Address"] != '\xa0']

df_new
# df['Address'][17]
# Out:
#                        Address              Cross_Street Keymap  \
# 0              3234 MCGOWEN ST         BLK TIERWESTER ST   493Z
# 1                 18000 LEE RD  BLK WILL CLAYTON PKWY OB   374H
# 2             4454 BLALOCK RD                              450G
# 3          8298 BELLAIRE BLVD                              530F
# 4             6100 WILCREST DR          BLK HIGH STAR DR   529C
# 5               7298 DIXIE DR                              534R
# 6            3398 MCCRAREY DR                              411R
# 7               3990 KIRBY DR                              492Y
# 8   3790 W SAM HOUSTON PKWY S                              529D
# 9         10798 CENTREPARK DR                              449M
# 10            7898 AIRLINE DR                              413T
# 11             1220 BLALOCK RD           BLK WESTVIEW DR   450Y
# 12                5300 NETT ST           BLK DETERING ST   492G
# 13           7698 KEMPWOOD DR                              451P
# 14       5602 SOUTHWEST FWY OB         CHIMNEY ROCK ENTR   491X
# 15             13500 DUNLAP ST         BLK HILLCROFT AVE   571J
# 16             5201 WRIGHT RD                              374D
# 17  3898 CLEAR LAKE CITY BLVD                              578X
# 18         2501 MONTROSE BLVD                              493N
# 19            9498 FONDREN RD                              530V
# 20   5500 EL CAMINO DEL REY ST              BLK ALDER DR   531B
# 21             8541 WINKLER DR           BLK MILREDGE ST   535U
# 22  5220 FUQUA GARDENS VIEW RD             BLK NELSON ST   571U
# 23         5000 ALLEN GENOA RD          BLK HERNANDEZ RD   577J
# 24  24771 E LAKE HOUSTON PKWY                              339J
#
#                 Time              Incident_Type Response
# 0   10/20/2019 19:18      CRASH/MAJOR/NON FATAL        N
# 1   10/20/2019 19:16      TRAFFIC HAZARD/URGENT        N
# 2   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 3   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 4   10/20/2019 19:10      CRASH/MAJOR/NON FATAL        N
# 5   10/20/2019 19:00                CRASH/MINOR        N
# 6   10/20/2019 18:48      CRASH/MAJOR/NON FATAL        N
# 7   10/20/2019 18:23           CRASH/MINOR/FSGI        N
# 8   10/20/2019 18:23      TRAFFIC HAZARD/URGENT        N
# 9   10/20/2019 18:23    CRASH/MINOR/DISTURBANCE        N
# 10  10/20/2019 18:10                CRASH/MINOR        N
# 11  10/20/2019 18:04                CRASH/MINOR        N
# 12  10/20/2019 17:58  TRAFFIC HAZARD/NON URGENT        N
# 13  10/20/2019 17:31    CRASH/MINOR/DISTURBANCE        N
# 14  10/20/2019 17:29                CRASH/MINOR        N
# 15  10/20/2019 17:22      CRASH/MAJOR/NON FATAL        N
# 16  10/20/2019 17:20      CRASH/MAJOR/NON FATAL        N
# 17  10/20/2019 16:50                CRASH/MINOR        N
# 18  10/20/2019 16:21      TRAFFIC HAZARD/URGENT        N
# 19  10/20/2019 16:17      CRASH/MAJOR/NON FATAL        N
# 20  10/20/2019 15:50    CRASH/MINOR/DISTURBANCE        N
# 21  10/20/2019 15:50      CRASH/MAJOR/NON FATAL        N
# 22  10/20/2019 15:17      CRASH/MAJOR/NON FATAL        N
# 23  10/20/2019 14:59           CRASH/MAJOR/FSRA        N
# 24  10/20/2019 01:10      CRASH/MAJOR/NON FATAL        N

# %%
location = []
len(df_new)
# Out:
# 25

# %%
for x in range(0,len(df_new)):
    try:
        print(df['Address'][x])
        row = requests.get('https://nominatim.openstreetmap.org/search?q='+ df['Address'][x] + ',Houston,Tx&format=json')
        lat.append(row.json()[0]['lat'])
        lon.append(row.json()[0]['lon'])
        location.append([row.json()[0]['lat'],row.json()[0]['lon']])
        print('-----APPEND DONE------')
    except:
        lat.append('')
        lon.append('')
        location.append('')
        pass
# 'https://nominatim.openstreetmap.org/search?q='+ df['Address'] + ',Houston,Tx
# Out:
# 3234 MCGOWEN ST
# -----APPEND DONE------
# 18000 LEE RD
# -----APPEND DONE------
# 4454 BLALOCK RD
# -----APPEND DONE------
# 8298 BELLAIRE BLVD
# -----APPEND DONE------
# 6100 WILCREST DR
# -----APPEND DONE------
# 7298 DIXIE DR
# -----APPEND DONE------
# 3398 MCCRAREY DR
# 3990 KIRBY DR
# -----APPEND DONE------
# 3790 W SAM HOUSTON PKWY S
# -----APPEND DONE------
# 10798 CENTREPARK DR
# -----APPEND DONE------
# 7898 AIRLINE DR
# -----APPEND DONE------
# 1220 BLALOCK RD
# -----APPEND DONE------
# 5300 NETT ST
# -----APPEND DONE------
# 7698 KEMPWOOD DR
# -----APPEND DONE------
# 5602 SOUTHWEST FWY OB
# -----APPEND DONE------
# 13500 DUNLAP ST
# -----APPEND DONE------
# 5201 WRIGHT RD
# -----APPEND DONE------
# 3898 CLEAR LAKE CITY BLVD
# -----APPEND DONE------
# 2501 MONTROSE BLVD
# -----APPEND DONE------
# 9498 FONDREN RD
# -----APPEND DONE------
# 5500 EL CAMINO DEL REY ST
# -----APPEND DONE------
# 8541 WINKLER DR
# -----APPEND DONE------
# 5220 FUQUA GARDENS VIEW RD
# -----APPEND DONE------
# 5000 ALLEN GENOA RD
# -----APPEND DONE------
# 24771 E LAKE HOUSTON PKWY
# -----APPEND DONE------

# %%
#df_new['lat'] = lat
#df_new['lon'] = lon

print(len(location))
print(len(df_new))
# Out:
# 25
# 25

# %%
df_new["location"] = location
df_new['lat'] = lat
df_new['lon'] = lon
df_new
# Out:
#                        Address              Cross_Street Keymap  \
# 0              3234 MCGOWEN ST         BLK TIERWESTER ST   493Z
# 1                 18000 LEE RD  BLK WILL CLAYTON PKWY OB   374H
# 2             4454 BLALOCK RD                              450G
# 3          8298 BELLAIRE BLVD                              530F
# 4             6100 WILCREST DR          BLK HIGH STAR DR   529C
# 5               7298 DIXIE DR                              534R
# 6            3398 MCCRAREY DR                              411R
# 7               3990 KIRBY DR                              492Y
# 8   3790 W SAM HOUSTON PKWY S                              529D
# 9         10798 CENTREPARK DR                              449M
# 10            7898 AIRLINE DR                              413T
# 11             1220 BLALOCK RD           BLK WESTVIEW DR   450Y
# 12                5300 NETT ST           BLK DETERING ST   492G
# 13           7698 KEMPWOOD DR                              451P
# 14       5602 SOUTHWEST FWY OB         CHIMNEY ROCK ENTR   491X
# 15             13500 DUNLAP ST         BLK HILLCROFT AVE   571J
# 16             5201 WRIGHT RD                              374D
# 17  3898 CLEAR LAKE CITY BLVD                              578X
# 18         2501 MONTROSE BLVD                              493N
# 19            9498 FONDREN RD                              530V
# 20   5500 EL CAMINO DEL REY ST              BLK ALDER DR   531B
# 21             8541 WINKLER DR           BLK MILREDGE ST   535U
# 22  5220 FUQUA GARDENS VIEW RD             BLK NELSON ST   571U
# 23         5000 ALLEN GENOA RD          BLK HERNANDEZ RD   577J
# 24  24771 E LAKE HOUSTON PKWY                              339J
#
#                 Time              Incident_Type Response  \
# 0   10/20/2019 19:18      CRASH/MAJOR/NON FATAL        N
# 1   10/20/2019 19:16      TRAFFIC HAZARD/URGENT        N
# 2   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 3   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 4   10/20/2019 19:10      CRASH/MAJOR/NON FATAL        N
# 5   10/20/2019 19:00                CRASH/MINOR        N
# 6   10/20/2019 18:48      CRASH/MAJOR/NON FATAL        N
# 7   10/20/2019 18:23           CRASH/MINOR/FSGI        N
# 8   10/20/2019 18:23      TRAFFIC HAZARD/URGENT        N
# 9   10/20/2019 18:23    CRASH/MINOR/DISTURBANCE        N
# 10  10/20/2019 18:10                CRASH/MINOR        N
# 11  10/20/2019 18:04                CRASH/MINOR        N
# 12  10/20/2019 17:58  TRAFFIC HAZARD/NON URGENT        N
# 13  10/20/2019 17:31    CRASH/MINOR/DISTURBANCE        N
# 14  10/20/2019 17:29                CRASH/MINOR        N
# 15  10/20/2019 17:22      CRASH/MAJOR/NON FATAL        N
# 16  10/20/2019 17:20      CRASH/MAJOR/NON FATAL        N
# 17  10/20/2019 16:50                CRASH/MINOR        N
# 18  10/20/2019 16:21      TRAFFIC HAZARD/URGENT        N
# 19  10/20/2019 16:17      CRASH/MAJOR/NON FATAL        N
# 20  10/20/2019 15:50    CRASH/MINOR/DISTURBANCE        N
# 21  10/20/2019 15:50      CRASH/MAJOR/NON FATAL        N
# 22  10/20/2019 15:17      CRASH/MAJOR/NON FATAL        N
# 23  10/20/2019 14:59           CRASH/MAJOR/FSRA        N
# 24  10/20/2019 01:10      CRASH/MAJOR/NON FATAL        N
#
#                                  location               lat                lon
# 0   [29.7343108421053, -95.3539768421053]  29.7343108421053  -95.3539768421053
# 1   [29.9834295518395, -95.3084490668896]  29.9834295518395  -95.3084490668896
# 2   [29.8354519024025, -95.5238863639241]  29.8354519024025  -95.5238863639241
# 3                 [29.705127, -95.532096]         29.705127         -95.532096
# 4               [29.7078931, -95.5712232]        29.7078931        -95.5712232
# 5                 [29.681355, -95.298829]         29.681355         -95.298829
# 6
# 7               [29.6953455, -95.4156217]        29.6953455        -95.4156217
# 8               [29.7190396, -95.5579928]        29.7190396        -95.5579928
# 9               [29.8304027, -95.5464154]        29.8304027        -95.5464154
# 10              [29.8645223, -95.3847632]        29.8645223        -95.3847632
# 11             [29.79029765, -95.5218804]       29.79029765        -95.5218804
# 12                [29.771971, -95.415581]         29.771971         -95.415581
# 13                [29.817157, -95.485204]         29.817157         -95.485204
# 14              [29.7313826, -95.3951555]        29.7313826        -95.3951555
# 15              [31.1256821, -95.4408581]        31.1256821        -95.4408581
# 16                [29.986818, -95.323549]         29.986818         -95.323549
# 17              [29.5958392, -95.1356775]        29.5958392        -95.1356775
# 18                 [29.74724, -95.391879]          29.74724         -95.391879
# 19               [29.675279, -95.5085639]         29.675279        -95.5085639
# 20                [29.723049, -95.477791]         29.723049         -95.477791
# 21                [29.672315, -95.262395]         29.672315         -95.262395
# 22              [29.6142616, -95.4617448]        29.6142616        -95.4617448
# 23                  [29.635301, -95.1933]         29.635301           -95.1933
# 24              [30.0302774, -95.1107233]        30.0302774        -95.1107233

# %%
df_new = df_new[(df_new['lat']!= '') & (df_new['lon']!= '')]
df_new
# Out:
#                        Address              Cross_Street Keymap  \
# 0              3234 MCGOWEN ST         BLK TIERWESTER ST   493Z
# 1                 18000 LEE RD  BLK WILL CLAYTON PKWY OB   374H
# 2             4454 BLALOCK RD                              450G
# 3          8298 BELLAIRE BLVD                              530F
# 4             6100 WILCREST DR          BLK HIGH STAR DR   529C
# 5               7298 DIXIE DR                              534R
# 7               3990 KIRBY DR                              492Y
# 8   3790 W SAM HOUSTON PKWY S                              529D
# 9         10798 CENTREPARK DR                              449M
# 10            7898 AIRLINE DR                              413T
# 11             1220 BLALOCK RD           BLK WESTVIEW DR   450Y
# 12                5300 NETT ST           BLK DETERING ST   492G
# 13           7698 KEMPWOOD DR                              451P
# 14       5602 SOUTHWEST FWY OB         CHIMNEY ROCK ENTR   491X
# 15             13500 DUNLAP ST         BLK HILLCROFT AVE   571J
# 16             5201 WRIGHT RD                              374D
# 17  3898 CLEAR LAKE CITY BLVD                              578X
# 18         2501 MONTROSE BLVD                              493N
# 19            9498 FONDREN RD                              530V
# 20   5500 EL CAMINO DEL REY ST              BLK ALDER DR   531B
# 21             8541 WINKLER DR           BLK MILREDGE ST   535U
# 22  5220 FUQUA GARDENS VIEW RD             BLK NELSON ST   571U
# 23         5000 ALLEN GENOA RD          BLK HERNANDEZ RD   577J
# 24  24771 E LAKE HOUSTON PKWY                              339J
#
#                 Time              Incident_Type Response  \
# 0   10/20/2019 19:18      CRASH/MAJOR/NON FATAL        N
# 1   10/20/2019 19:16      TRAFFIC HAZARD/URGENT        N
# 2   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 3   10/20/2019 19:14      CRASH/MAJOR/NON FATAL        N
# 4   10/20/2019 19:10      CRASH/MAJOR/NON FATAL        N
# 5   10/20/2019 19:00                CRASH/MINOR        N
# 7   10/20/2019 18:23           CRASH/MINOR/FSGI        N
# 8   10/20/2019 18:23      TRAFFIC HAZARD/URGENT        N
# 9   10/20/2019 18:23    CRASH/MINOR/DISTURBANCE        N
# 10  10/20/2019 18:10                CRASH/MINOR        N
# 11  10/20/2019 18:04                CRASH/MINOR        N
# 12  10/20/2019 17:58  TRAFFIC HAZARD/NON URGENT        N
# 13  10/20/2019 17:31    CRASH/MINOR/DISTURBANCE        N
# 14  10/20/2019 17:29                CRASH/MINOR        N
# 15  10/20/2019 17:22      CRASH/MAJOR/NON FATAL        N
# 16  10/20/2019 17:20      CRASH/MAJOR/NON FATAL        N
# 17  10/20/2019 16:50                CRASH/MINOR        N
# 18  10/20/2019 16:21      TRAFFIC HAZARD/URGENT        N
# 19  10/20/2019 16:17      CRASH/MAJOR/NON FATAL        N
# 20  10/20/2019 15:50    CRASH/MINOR/DISTURBANCE        N
# 21  10/20/2019 15:50      CRASH/MAJOR/NON FATAL        N
# 22  10/20/2019 15:17      CRASH/MAJOR/NON FATAL        N
# 23  10/20/2019 14:59           CRASH/MAJOR/FSRA        N
# 24  10/20/2019 01:10      CRASH/MAJOR/NON FATAL        N
#
#                                  location               lat                lon
# 0   [29.7343108421053, -95.3539768421053]  29.7343108421053  -95.3539768421053
# 1   [29.9834295518395, -95.3084490668896]  29.9834295518395  -95.3084490668896
# 2   [29.8354519024025, -95.5238863639241]  29.8354519024025  -95.5238863639241
# 3                 [29.705127, -95.532096]         29.705127         -95.532096
# 4               [29.7078931, -95.5712232]        29.7078931        -95.5712232
# 5                 [29.681355, -95.298829]         29.681355         -95.298829
# 7               [29.6953455, -95.4156217]        29.6953455        -95.4156217
# 8               [29.7190396, -95.5579928]        29.7190396        -95.5579928
# 9               [29.8304027, -95.5464154]        29.8304027        -95.5464154
# 10              [29.8645223, -95.3847632]        29.8645223        -95.3847632
# 11             [29.79029765, -95.5218804]       29.79029765        -95.5218804
# 12                [29.771971, -95.415581]         29.771971         -95.415581
# 13                [29.817157, -95.485204]         29.817157         -95.485204
# 14              [29.7313826, -95.3951555]        29.7313826        -95.3951555
# 15              [31.1256821, -95.4408581]        31.1256821        -95.4408581
# 16                [29.986818, -95.323549]         29.986818         -95.323549
# 17              [29.5958392, -95.1356775]        29.5958392        -95.1356775
# 18                 [29.74724, -95.391879]          29.74724         -95.391879
# 19               [29.675279, -95.5085639]         29.675279        -95.5085639
# 20                [29.723049, -95.477791]         29.723049         -95.477791
# 21                [29.672315, -95.262395]         29.672315         -95.262395
# 22              [29.6142616, -95.4617448]        29.6142616        -95.4617448
# 23                  [29.635301, -95.1933]         29.635301           -95.1933
# 24              [30.0302774, -95.1107233]        30.0302774        -95.1107233

# %%
df_new.to_csv('data/live_incidents.csv',index=False)

# %% [markdown]
# # FInal Json format needed -
#
#     {
#     "location": [29.6874560555556,-95.530489489899],
#     "time": "10/19/2019 01:46",
#     "type":"CRASH/MINOR	",
#     "address": "8602 SOUTHWEST FWY OB"
#   }

# %%
df_live = pd.DataFrame({'location':df_new["location"], 'time':df_new["Time"], 
                        'type':df_new["Incident_Type"], 'address':df_new["Address"]})

# %%
df_live
# Out:
#                                  location              time  \
# 0   [29.7343108421053, -95.3539768421053]  10/20/2019 19:18
# 1   [29.9834295518395, -95.3084490668896]  10/20/2019 19:16
# 2   [29.8354519024025, -95.5238863639241]  10/20/2019 19:14
# 3                 [29.705127, -95.532096]  10/20/2019 19:14
# 4               [29.7078931, -95.5712232]  10/20/2019 19:10
# 5                 [29.681355, -95.298829]  10/20/2019 19:00
# 7               [29.6953455, -95.4156217]  10/20/2019 18:23
# 8               [29.7190396, -95.5579928]  10/20/2019 18:23
# 9               [29.8304027, -95.5464154]  10/20/2019 18:23
# 10              [29.8645223, -95.3847632]  10/20/2019 18:10
# 11             [29.79029765, -95.5218804]  10/20/2019 18:04
# 12                [29.771971, -95.415581]  10/20/2019 17:58
# 13                [29.817157, -95.485204]  10/20/2019 17:31
# 14              [29.7313826, -95.3951555]  10/20/2019 17:29
# 15              [31.1256821, -95.4408581]  10/20/2019 17:22
# 16                [29.986818, -95.323549]  10/20/2019 17:20
# 17              [29.5958392, -95.1356775]  10/20/2019 16:50
# 18                 [29.74724, -95.391879]  10/20/2019 16:21
# 19               [29.675279, -95.5085639]  10/20/2019 16:17
# 20                [29.723049, -95.477791]  10/20/2019 15:50
# 21                [29.672315, -95.262395]  10/20/2019 15:50
# 22              [29.6142616, -95.4617448]  10/20/2019 15:17
# 23                  [29.635301, -95.1933]  10/20/2019 14:59
# 24              [30.0302774, -95.1107233]  10/20/2019 01:10
#
#                          type                     address
# 0       CRASH/MAJOR/NON FATAL             3234 MCGOWEN ST
# 1       TRAFFIC HAZARD/URGENT                18000 LEE RD
# 2       CRASH/MAJOR/NON FATAL            4454 BLALOCK RD
# 3       CRASH/MAJOR/NON FATAL         8298 BELLAIRE BLVD
# 4       CRASH/MAJOR/NON FATAL            6100 WILCREST DR
# 5                 CRASH/MINOR              7298 DIXIE DR
# 7            CRASH/MINOR/FSGI              3990 KIRBY DR
# 8       TRAFFIC HAZARD/URGENT  3790 W SAM HOUSTON PKWY S
# 9     CRASH/MINOR/DISTURBANCE        10798 CENTREPARK DR
# 10                CRASH/MINOR            7898 AIRLINE DR
# 11                CRASH/MINOR             1220 BLALOCK RD
# 12  TRAFFIC HAZARD/NON URGENT                5300 NETT ST
# 13    CRASH/MINOR/DISTURBANCE           7698 KEMPWOOD DR
# 14                CRASH/MINOR       5602 SOUTHWEST FWY OB
# 15      CRASH/MAJOR/NON FATAL             13500 DUNLAP ST
# 16      CRASH/MAJOR/NON FATAL             5201 WRIGHT RD
# 17                CRASH/MINOR  3898 CLEAR LAKE CITY BLVD
# 18      TRAFFIC HAZARD/URGENT         2501 MONTROSE BLVD
# 19      CRASH/MAJOR/NON FATAL            9498 FONDREN RD
# 20    CRASH/MINOR/DISTURBANCE   5500 EL CAMINO DEL REY ST
# 21      CRASH/MAJOR/NON FATAL             8541 WINKLER DR
# 22      CRASH/MAJOR/NON FATAL  5220 FUQUA GARDENS VIEW RD
# 23           CRASH/MAJOR/FSRA         5000 ALLEN GENOA RD
# 24      CRASH/MAJOR/NON FATAL  24771 E LAKE HOUSTON PKWY
